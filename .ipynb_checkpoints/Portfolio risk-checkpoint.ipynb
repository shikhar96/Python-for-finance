# %%
#Importing packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader import data as wb

# %%
#Loading portfolio data
tickers = ['MOREPENLAB.NS','RECLTD.NS','TALWALKARS.NS','FCONSUMER.NS']
mydata = pd.DataFrame()
for t in tickers:
    mydata[t] = wb.DataReader(t, data_source = 'yahoo', start = '2013-1-1')['Adj Close']
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1224 entries, 2013-01-01 to 2017-12-15
# Data columns (total 4 columns):
# MOREPENLAB.NS    1160 non-null float64
# RECLTD.NS        1221 non-null float64
# TALWALKARS.NS    1001 non-null float64
# FCONSUMER.NS     775 non-null float64
# dtypes: float64(4)
# memory usage: 47.8 KB

# %%
mydata.head()
# Out:
#             MOREPENLAB.NS  RECLTD.NS  TALWALKARS.NS  FCONSUMER.NS
# Date
# 2013-01-01           3.80  76.191162     187.856171          9.90
# 2013-01-02           3.80  77.984978     188.045364          9.75
# 2013-01-03           3.70  80.706093     191.309586          9.95
# 2013-01-04           3.85  80.888504     187.950775          9.80
# 2013-01-07           3.90  78.729858     187.856171          9.95

# %%
mydata.tail()
# Out:
#             MOREPENLAB.NS   RECLTD.NS  TALWALKARS.NS  FCONSUMER.NS
# Date
# 2017-12-11      25.650000  151.199997     303.549988     67.000000
# 2017-12-12      25.049999  147.000000     302.250000     65.300003
# 2017-12-13      24.950001  145.750000     302.700012     63.700001
# 2017-12-14      24.600000  144.000000     300.799988     63.450001
# 2017-12-15      25.100000  146.649994     303.399994     67.849998

# %%
#Normalizing prices to 100 and plotting chart
(mydata/mydata.iloc[0]*100).plot(figsize = (15,6))
plt.show()

# %%
#Weights in the portfolio
weights = np.array([0.3575, 0.1194, 0.247, 0.2761])

# %%
#Calculating simple return
returns = (mydata/mydata.shift(1)) - 1
returns.head()
# Out:
#             MOREPENLAB.NS  RECLTD.NS  TALWALKARS.NS  FCONSUMER.NS
# Date
# 2013-01-01            NaN        NaN            NaN           NaN
# 2013-01-02       0.000000   0.023544       0.001007     -0.015152
# 2013-01-03      -0.026316   0.034893       0.017359      0.020513
# 2013-01-04       0.040541   0.002260      -0.017557     -0.015075
# 2013-01-07       0.012987  -0.026687      -0.000503      0.015306

# %%
#Calculating portfolio variance
port_var = np.dot(weights.T, np.dot(returns.cov()*250, weights))
print(port_var)
# Out:
# 0.104368671257

# %%
#Calculating portfolio volatility
port_vol = port_var ** 0.5
print(port_vol)
# Out:
# 0.323061404777
